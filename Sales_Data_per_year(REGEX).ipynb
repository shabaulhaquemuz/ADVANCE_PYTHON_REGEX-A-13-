# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install feather-format
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for feather-format: filename=feather_format-0.4.1-py3-none-any.whl size=2453 sha256=262cff3ab5e7f04e64b7ee75f73199a5589d98c2f31ca453d5013834ee9e6c6b
#   Stored in directory: c:\users\shaba\appdata\local\pip\cache\wheels\dd\02\6b\2f0f7e1c0454094c880e63076da142e67f1ba72f82baa6195f
# Successfully built feather-format
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_feather("Sales_data.ftr")
print(df)
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1          None                        None             None       None
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df.isnull()
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0          False    False             False       False       False
# 1           True     True              True        True        True
# 2          False    False             False       False       False
# 3          False    False             False       False       False
# 4          False    False             False       False       False
# ...          ...      ...               ...         ...         ...
# 186845     False    False             False       False       False
# 186846     False    False             False       False       False
# 186847     False    False             False       False       False
# 186848     False    False             False       False       False
# 186849     False    False             False       False       False
#
#         Purchase Address
# 0                  False
# 1                   True
# 2                  False
# 3                  False
# ...

# %%
df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
copied_df=df.copy()
print(copied_df)
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1          None                        None             None       None
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
copied_df.isnull()
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0          False    False             False       False       False
# 1           True     True              True        True        True
# 2          False    False             False       False       False
# 3          False    False             False       False       False
# 4          False    False             False       False       False
# ...          ...      ...               ...         ...         ...
# 186845     False    False             False       False       False
# 186846     False    False             False       False       False
# 186847     False    False             False       False       False
# 186848     False    False             False       False       False
# 186849     False    False             False       False       False
#
#         Purchase Address
# 0                  False
# 1                   True
# 2                  False
# 3                  False
# ...

# %%
copied_df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
copied_df.dropna(inplace=True)

# %%
copied_df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
duplicates=copied_df.duplicated().sum()
print(duplicates)
# Out:
# 618

# %%
cleaned_copied_df=copied_df.drop_duplicates

# %%
print(df.describe())
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
print(copied_df.shape)
# Out:
# (186305, 6)

# %%
print(copied_df.dtypes)
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
#order date me se month nikalna ha,,, unique month dekhna hai nikal aya ni... check datatype of month... make new column calleed as sales = quantity ordered*price of each

# %%
copied_df["Order Date"]=pd.to_datetime(copied_df["Order Date"],errors="coerce")
copied_df = copied_df.dropna(subset=["Order Date"])
copied_df["Month"]=copied_df["Order Date"].dt.month
#copied_df["Month"]=copied_df["Order Date"].dt.month

# %%
copied_df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#                 Order Date                         Purchase Address  Month
# ...

# %%
copied_df['Month'].unique()
# Out:
# array([ 4,  5,  8,  9, 12,  1,  2,  3,  7,  6, 11, 10])

# %%
copied_df["Month"].dtype
# Out:
# dtype('int32')

# %%
copied_df["Quantity Ordered"] = pd.to_numeric(copied_df["Quantity Ordered"], errors='coerce')
copied_df["Price Each"] = pd.to_numeric(copied_df["Price Each"], errors='coerce')

# %%
#copied_df[['Year', 'Month', 'Day']] = copied_df['Order Date'].str.split('-', expand=True)
copied_df["sales"]=copied_df["Quantity Ordered"] * copied_df["Price Each"]
copied_df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
#1. . Total Sales
copied_df["sales"].sum()
# Out:
# 34492035.97

# %%
# 2. sales by month
copied_df.groupby("Month")["sales"].sum()
# Out:
# Month
# 1     1822256.73
# 2     2202022.42
# 3     2807100.38
# 4     3390670.24
# 5     3152606.75
# 6     2577802.26
# 7     2647775.76
# 8     2244467.88
# 9     2097560.13
# 10    3736726.88
# 11    3199603.20
# 12    4613443.34
# Name: sales, dtype: float64

# %%
# 3. Best-Selling Product
best_product=copied_df.groupby("Product")["sales"].sum().sort_values(ascending=False)
print(best_product.head(1))
# Out:
# Product
# Macbook Pro Laptop    8037600.0
# Name: sales, dtype: float64

# %%
#4.Show unique products sold
print(copied_df["Product"].unique())
# Out:
# ['USB-C Charging Cable' 'Bose SoundSport Headphones' 'Google Phone'
#  'Wired Headphones' 'Macbook Pro Laptop' 'Lightning Charging Cable'
#  '27in 4K Gaming Monitor' 'AA Batteries (4-pack)'
#  'Apple Airpods Headphones' 'AAA Batteries (4-pack)' 'iPhone'
#  'Flatscreen TV' '27in FHD Monitor' '20in Monitor' 'LG Dryer'
#  'ThinkPad Laptop' 'Vareebadd Phone' 'LG Washing Machine'
#  '34in Ultrawide Monitor']

# %%
#5.Count how many orders per product
print(copied_df.groupby("Product")["Quantity Ordered"].sum())
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int64

# %%
#6.Total revenue per product
print(copied_df.groupby("Product")["sales"].sum())
# Out:
# Product
# 20in Monitor                   454148.71
# 27in 4K Gaming Monitor        2435097.56
# 27in FHD Monitor              1132424.50
# 34in Ultrawide Monitor        2355558.01
# AA Batteries (4-pack)          106118.40
# AAA Batteries (4-pack)          92740.83
# Apple Airpods Headphones      2349150.00
# Bose SoundSport Headphones    1345565.43
# Flatscreen TV                 1445700.00
# Google Phone                  3319200.00
# LG Dryer                       387600.00
# LG Washing Machine             399600.00
# Lightning Charging Cable       347094.15
# Macbook Pro Laptop            8037600.00
# ThinkPad Laptop               4129958.70
# USB-C Charging Cable           286501.25
# Vareebadd Phone                827200.00
# Wired Headphones               246478.43
# iPhone                        4794300.00
# Name: sales, dtype: float64

# %%
#7. Highest sales row (largest single order)
copied_df[copied_df["sales"]==copied_df["sales"].max()]
# Out:
#        Order ID             Product  Quantity Ordered  Price Each  \
# 4717     181069  Macbook Pro Laptop                 2      1700.0
# 5219     181544  Macbook Pro Laptop                 2      1700.0
# 92026    210292  Macbook Pro Laptop                 2      1700.0
# 127265   200528  Macbook Pro Laptop                 2      1700.0
#
#                 Order Date                       Purchase Address  Month  \
# 4717   2019-04-27 21:01:00   668 Park St, San Francisco, CA 94016      4
# 5219   2019-04-22 12:48:00   731 11th St, New York City, NY 10001      4
# 92026  2019-06-08 09:00:00  953 Ridge St, San Francisco, CA 94016      6
# 127265 2019-05-13 13:40:00           643 4th St, Boston, MA 02215      5
#
#          sales
# 4717    3400.0
# 5219    3400.0
# 92026   3400.0
# 127265  3400.0

# %%
#8. Add a column to check if sales > 100
copied_df["check_1000"]=copied_df["sales"]>100
copied_df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...
